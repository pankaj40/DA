# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df,hue='sex')

# %%
df.pivot_table(index='sex',columns='time')
# Out:
#             size                 tip           total_bill
# time       Lunch    Dinner     Lunch    Dinner      Lunch     Dinner
# sex
# Male    2.363636  2.701613  2.882121  3.144839  18.048485  21.461452
# Female  2.457143  2.461538  2.582857  3.002115  16.339143  19.213077

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df.groupby('time')['sex'].describe()
# Out:
#        count unique     top freq
# time
# Lunch     68      2  Female   35
# Dinner   176      2    Male  124

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
x=df[(df['time']=='Lunch') & (df['sex']=='Male')].shape[0]

# %%
y=df[(df['time']=='Lunch') & (df['sex']=='Female')].shape[0]

# %%
df.groupby('time')['sex'].describe().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df['time'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='sex',style='smoker',size='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='time',y='tip',kind='strip',data=df,hue='sex')

# %%
sns.catplot(x='time',y='tip',kind='swarm',data=df,hue='smoker')

# %%
sns.boxplot(df['tip'])
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.catplot(x='day',y='tip',kind='box',data=df,hue='sex')

# %%
sns.violinplot(df['tip'])
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.catplot(x='day',y='tip',kind='violin',data=df,hue='sex',split=True)

# %%
sns.barplot(df['tip'])
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.catplot(x='time',y='tip',kind='bar',data=df,hue='sex')

# %%
sns.countplot(df['sex'])
# Out:
# C:\Users\pc\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.catplot(x='time',kind='count',data=df,hue='sex')

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
x=df.pivot_table(index='day',columns='time',values='tip',aggfunc='sum')

# %%
df[(df['time']=='Lunch') & (df['day']=='Sat')].shape[0]
# Out:
# 0

# %%
sns.heatmap(x,linewidth=0.5,annot=True)
# Out:
# <AxesSubplot:xlabel='time', ylabel='day'>

# %%
sns.clustermap(x)

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',kind='reg',data=df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.displot(df['total_bill'])

# %%
sns.displot(df[df['size']==2]['tip'])
